# %%
import pandas as pd

data=pd.read_csv("df_replaced.csv" )

#data


# Specify the columns you want to keep
#columns_to_keep = ['datetime','Load']

# Use indexing to select the desired columns
#df = data[columns_to_keep]
# set the 'datetime_column' as the index
#df.set_index('datetime', inplace=True)
data
# Out:
#                   datetime        Load
# 0      2019-03-21 00:00:00  352.862799
# 1      2019-03-21 01:00:00  330.444853
# 2      2019-03-21 02:00:00  287.419792
# 3      2019-03-21 03:00:00  258.110368
# 4      2019-03-21 04:00:00  247.745866
# ...                    ...         ...
# 22003  2021-09-22 19:00:00  632.235500
# 22004  2021-09-22 20:00:00  612.703162
# 22005  2021-09-22 21:00:00  589.574385
# 22006  2021-09-22 22:00:00  561.323968
# 22007  2021-09-22 23:00:00  522.105758
#
# [22008 rows x 2 columns]

# %%
data['datetime'] = pd.to_datetime(data['datetime'])

# %%
df=data

# %%
df.dtypes
# Out:
# datetime    datetime64[ns]
# Load               float64
# dtype: object

# %%
from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 4)

# %%
df.set_index('datetime', inplace=True)
df.sort_index(inplace=True)
X = df.drop(labels=[], axis=1)
y = df['Load']

# %%
y
# Out:
# datetime
# 2019-03-21 00:00:00    352.862799
# 2019-03-21 01:00:00    330.444853
# 2019-03-21 02:00:00    287.419792
# 2019-03-21 03:00:00    258.110368
# 2019-03-21 04:00:00    247.745866
#                           ...
# 2021-09-22 19:00:00    632.235500
# 2021-09-22 20:00:00    612.703162
# 2021-09-22 21:00:00    589.574385
# 2021-09-22 22:00:00    561.323968
# 2021-09-22 23:00:00    522.105758
# Name: Load, Length: 22008, dtype: float64

# %%
X
# Out:
#                            Load
# datetime
# 2019-03-21 00:00:00  352.862799
# 2019-03-21 01:00:00  330.444853
# 2019-03-21 02:00:00  287.419792
# 2019-03-21 03:00:00  258.110368
# 2019-03-21 04:00:00  247.745866
# ...                         ...
# 2021-09-22 19:00:00  632.235500
# 2021-09-22 20:00:00  612.703162
# 2021-09-22 21:00:00  589.574385
# 2021-09-22 22:00:00  561.323968
# 2021-09-22 23:00:00  522.105758
#
# [22008 rows x 1 columns]

# %%
for train_index, test_index in tss.split(X):
    X_train, X_test = X.iloc[train_index, :], X.iloc[test_index,:]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
X_train.index
# Out:
# DatetimeIndex(['2019-03-21 00:00:00', '2019-03-21 01:00:00',
#                '2019-03-21 02:00:00', '2019-03-21 03:00:00',
#                '2019-03-21 04:00:00', '2019-03-21 05:00:00',
#                '2019-03-21 06:00:00', '2019-03-21 07:00:00',
#                '2019-03-21 08:00:00', '2019-03-21 09:00:00',
#                ...
#                '2021-03-23 05:00:00', '2021-03-23 06:00:00',
#                '2021-03-23 07:00:00', '2021-03-23 08:00:00',
#                '2021-03-23 09:00:00', '2021-03-23 10:00:00',
#                '2021-03-23 11:00:00', '2021-03-23 12:00:00',
#                '2021-03-23 13:00:00', '2021-03-23 14:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=17607, freq=None)

# %%
X_test[:40]
# Out:
#                            Load
# datetime
# 2021-03-23 15:00:00  298.028399
# 2021-03-23 16:00:00  302.942181
# 2021-03-23 17:00:00  310.834565
# 2021-03-23 18:00:00  321.126720
# 2021-03-23 19:00:00  351.975302
# 2021-03-23 20:00:00  381.193585
# 2021-03-23 21:00:00  372.975475
# 2021-03-23 22:00:00  361.653087
# 2021-03-23 23:00:00  348.730577
# 2021-03-24 00:00:00  327.879940
# 2021-03-24 01:00:00  296.560175
# 2021-03-24 02:00:00  270.789430
# 2021-03-24 03:00:00  256.314881
# 2021-03-24 04:00:00  248.099433
# 2021-03-24 05:00:00  246.623878
# 2021-03-24 06:00:00  246.162295
# 2021-03-24 07:00:00  235.640568
# 2021-03-24 08:00:00  240.580521
# 2021-03-24 09:00:00  255.916898
# 2021-03-24 10:00:00  283.952127
# 2021-03-24 11:00:00  303.712657
# 2021-03-24 12:00:00  309.412755
# 2021-03-24 13:00:00  306.161168
# 2021-03-24 14:00:00  297.503773
# 2021-03-24 15:00:00  291.394602
# 2021-03-24 16:00:00  297.254720
# 2021-03-24 17:00:00  301.377388
# 2021-03-24 18:00:00  311.993927
# 2021-03-24 19:00:00  349.286351
# 2021-03-24 20:00:00  381.911799
# 2021-03-24 21:00:00  371.744897
# 2021-03-24 22:00:00  356.325910
# 2021-03-24 23:00:00  342.898926
# 2021-03-25 00:00:00  328.794386
# 2021-03-25 01:00:00  297.100291
# 2021-03-25 02:00:00  271.102754
# 2021-03-25 03:00:00  256.956414
# 2021-03-25 04:00:00  250.083746
# 2021-03-25 05:00:00  246.782099
# 2021-03-25 06:00:00  245.798810

# %%
X_test.index
# Out:
# DatetimeIndex(['2021-03-23 15:00:00', '2021-03-23 16:00:00',
#                '2021-03-23 17:00:00', '2021-03-23 18:00:00',
#                '2021-03-23 19:00:00', '2021-03-23 20:00:00',
#                '2021-03-23 21:00:00', '2021-03-23 22:00:00',
#                '2021-03-23 23:00:00', '2021-03-24 00:00:00',
#                ...
#                '2021-09-22 14:00:00', '2021-09-22 15:00:00',
#                '2021-09-22 16:00:00', '2021-09-22 17:00:00',
#                '2021-09-22 18:00:00', '2021-09-22 19:00:00',
#                '2021-09-22 20:00:00', '2021-09-22 21:00:00',
#                '2021-09-22 22:00:00', '2021-09-22 23:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=4401, freq=None)

# %%
def price2num(x):
    if type(x) == str:
        x = x.strip('$').replace(',', '')
    return float(x)


#function to convert price from string to floats
y_train=y_train.apply(price2num)
y_train.groupby('datetime').mean().plot()
y_test=y_test.apply(price2num)
y_test.groupby('datetime').mean().plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
print(X_train.shape, X_test.shape)
# Out:
# (17607, 1) (4401, 1)

# %%
y_train.shape
# Out:
# (17607,)

# %%
from sklearn.preprocessing import MinMaxScaler

f_columns = ['Load']  # Define a list of column names to be transformed

f_transformer = MinMaxScaler()  # Create an instance of MinMaxScaler for feature transformation
t_transformer = MinMaxScaler()  # Create an instance of MinMaxScaler for target transformation

f_transformer = f_transformer.fit(X_train[f_columns].to_numpy())  # Fit the feature transformer to the training data
t_transformer = t_transformer.fit(y_train.to_numpy().reshape(-1, 1))  # Fit the target transformer to the training data

X_train.loc[:, f_columns] = f_transformer.transform(X_train[f_columns].to_numpy())  # Apply feature transformation to the training data
y_train = t_transformer.transform(y_train.to_numpy().reshape(-1, 1))  # Apply target transformation to the training data

X_test.loc[:, f_columns] = f_transformer.transform(X_test[f_columns].to_numpy())  # Apply feature transformation to the test data
y_test = t_transformer.transform(y_test.to_numpy().reshape(-1, 1))  # Apply target transformation to the test data
# Out:
# <ipython-input-44-4d9097f2dad2>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train.loc[:, f_columns] = f_transformer.transform(X_train[f_columns].to_numpy())  # Apply feature transformation to the training data
# <ipython-input-44-4d9097f2dad2>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.loc[:, f_columns] = f_transformer.transform(X_test[f_columns].to_numpy())  # Apply feature transformation to the test data

# %%
import numpy as np

def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X[i:(i + time_steps)]
        Xs.append(v)
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 24  # Set the number of time steps to 24

X_train, y_train = create_dataset(X_train, y_train, time_steps)  # Create the training dataset using the 'create_dataset' function

X_test, y_test = create_dataset(X_test, y_test, time_steps)  # Create the test dataset using the 'create_dataset' function



print(X_train.shape,y_train.shape,X_test.shape,  y_test.shape)
# Out:
# (17583, 24, 1) (17583, 1) (4377, 24, 1) (4377, 1)

# %%
import math
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

import tensorflow as tf
from keras.callbacks import EarlyStopping

# %%
def build_model(num_layers, units, dropout_rates):
    model = keras.Sequential()

    for i in range(num_layers):
        return_sequences = (i != num_layers - 1)  # Set return_sequences=True for all but the last layer

        model.add(layers.LSTM(units=units[i], input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=return_sequences))
        model.add(layers.Dropout(dropout_rates[i]))

    model.add(layers.Dense(1))
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0007686009471966071),
        loss='mean_squared_error'
      # , metrics=['mae','mape']
        )
    return model

# Optimized hyperparameters
num_layers = 1
units = [238 ]
dropout_rates = [0.21281066522600117]


model = build_model(num_layers, units, dropout_rates)

# Create an instance of EarlyStopping callback
custom_early_stopping = EarlyStopping(
    monitor='val_loss',  # Quantity to monitor for early stopping (validation loss)
    patience=20,  # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    start_from_epoch=20
)

history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=64,
    validation_split=0.2
    ,callbacks=[custom_early_stopping]
   )
# Out:
# Epoch 1/200
# 220/220 [==============================] - 23s 93ms/step - loss: 0.0135 - val_loss: 0.0036
# Epoch 2/200
# 220/220 [==============================] - 19s 85ms/step - loss: 0.0043 - val_loss: 0.0024
# Epoch 3/200
# 220/220 [==============================] - 21s 94ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 4/200
# 220/220 [==============================] - 20s 89ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 5/200
# 220/220 [==============================] - 20s 91ms/step - loss: 0.0021 - val_loss: 0.0010
# Epoch 6/200
# 220/220 [==============================] - 20s 90ms/step - loss: 0.0018 - val_loss: 8.8522e-04
# Epoch 7/200
# 220/220 [==============================] - 19s 85ms/step - loss: 0.0017 - val_loss: 8.2449e-04
# Epoch 8/200
# 220/220 [==============================] - 20s 90ms/step - loss: 0.0016 - val_loss: 7.6439e-04
# Epoch 9/200
# 220/220 [==============================] - 19s 85ms/step - loss: 0.0015 - val_loss: 6.9127e-04
# Epoch 10/200
# 220/220 [==============================] - 20s 89ms/step - loss: 0.0013 - val_loss: 6.0593e-04
# Epoch 11/200
# 220/220 [==============================] - 19s 85ms/step - loss: 0.0012 - val_loss: 6.2639e-04
# Epoch 12/200
# 220/220 [==============================] - 20s 90ms/step - loss: 0.0012 - val_loss: 4.9780e-04
# Epoch 13/200
# 220/220 [==============================] - 19s 85ms/step - loss: 0.0011 - val_loss: 5.4407e-04
# Epoch 14/200
# 220/220 [==============================] - 20s 90ms/step - loss: 0.0010 - val_loss: 5.0364e-04
# Epoch 15/200
# 220/220 [==============================] - 19s 85ms/step - loss: 9.7970e-04 - val_loss: 4.2924e-04
# Epoch 16/200
# 220/220 [==============================] - 20s 89ms/step - loss: 9.1140e-04 - val_loss: 4.0446e-04
# Epoch 17/200
# 220/220 [==============================] - 19s 85ms/step - loss: 9.0432e-04 - val_loss: 3.7810e-04
# Epoch 18/200
# 220/220 [==============================] - 20s 90ms/step - loss: 8.4574e-04 - val_loss: 3.6936e-04
# Epoch 19/200
# 220/220 [==============================] - 19s 85ms/step - loss: 8.2500e-04 - val_loss: 3.3441e-04
# Epoch 20/200
# 220/220 [==============================] - 20s 89ms/step - loss: 8.3986e-04 - val_loss: 3.3397e-04
# Epoch 21/200
# 220/220 [==============================] - 19s 85ms/step - loss: 8.4262e-04 - val_loss: 3.6937e-04
# Epoch 22/200
# 220/220 [==============================] - 20s 90ms/step - loss: 8.1533e-04 - val_loss: 3.0676e-04
# Epoch 23/200
# 220/220 [==============================] - 19s 85ms/step - loss: 7.5133e-04 - val_loss: 3.0957e-04
# Epoch 24/200
# 220/220 [==============================] - 20s 90ms/step - loss: 7.4842e-04 - val_loss: 3.1538e-04
# Epoch 25/200
# 220/220 [==============================] - 19s 85ms/step - loss: 7.5059e-04 - val_loss: 3.2042e-04
# Epoch 26/200
# 220/220 [==============================] - 20s 90ms/step - loss: 7.2730e-04 - val_loss: 3.2306e-04
# Epoch 27/200
# 220/220 [==============================] - 19s 85ms/step - loss: 7.0971e-04 - val_loss: 2.8169e-04
# Epoch 28/200
# 220/220 [==============================] - 20s 90ms/step - loss: 7.0361e-04 - val_loss: 2.9033e-04
# Epoch 29/200
# 220/220 [==============================] - 19s 85ms/step - loss: 6.9005e-04 - val_loss: 2.8309e-04
# Epoch 30/200
# 220/220 [==============================] - 20s 90ms/step - loss: 6.6708e-04 - val_loss: 2.8893e-04
# Epoch 31/200
# 220/220 [==============================] - 19s 85ms/step - loss: 6.4927e-04 - val_loss: 3.1089e-04
# Epoch 32/200
# 220/220 [==============================] - 20s 89ms/step - loss: 6.4447e-04 - val_loss: 3.3964e-04
# Epoch 33/200
# 220/220 [==============================] - 19s 85ms/step - loss: 6.3288e-04 - val_loss: 2.6420e-04
# Epoch 34/200
# 220/220 [==============================] - 20s 89ms/step - loss: 6.1765e-04 - val_loss: 2.5281e-04
# Epoch 35/200
# 220/220 [==============================] - 20s 89ms/step - loss: 5.9262e-04 - val_loss: 2.5227e-04
# Epoch 36/200
# 220/220 [==============================] - 19s 86ms/step - loss: 5.9607e-04 - val_loss: 2.8955e-04
# Epoch 37/200
# 220/220 [==============================] - 20s 90ms/step - loss: 5.9445e-04 - val_loss: 2.5686e-04
# Epoch 38/200
# 220/220 [==============================] - 19s 85ms/step - loss: 5.8079e-04 - val_loss: 2.7125e-04
# Epoch 39/200
# 220/220 [==============================] - 20s 89ms/step - loss: 5.7661e-04 - val_loss: 2.5206e-04
# Epoch 40/200
# 220/220 [==============================] - 19s 85ms/step - loss: 5.5083e-04 - val_loss: 2.5136e-04
# Epoch 41/200
# 220/220 [==============================] - 20s 89ms/step - loss: 5.3407e-04 - val_loss: 2.4671e-04
# Epoch 42/200
# 220/220 [==============================] - 19s 85ms/step - loss: 5.1706e-04 - val_loss: 2.9784e-04
# Epoch 43/200
# 220/220 [==============================] - 20s 89ms/step - loss: 5.1640e-04 - val_loss: 2.2377e-04
# Epoch 44/200
# 220/220 [==============================] - 19s 85ms/step - loss: 5.1360e-04 - val_loss: 2.3661e-04
# Epoch 45/200
# 220/220 [==============================] - 20s 89ms/step - loss: 4.9602e-04 - val_loss: 2.2843e-04
# Epoch 46/200
# 220/220 [==============================] - 19s 86ms/step - loss: 4.8476e-04 - val_loss: 2.3068e-04
# Epoch 47/200
# 220/220 [==============================] - 20s 90ms/step - loss: 4.9521e-04 - val_loss: 2.3318e-04
# Epoch 48/200
# 220/220 [==============================] - 19s 85ms/step - loss: 4.7881e-04 - val_loss: 2.2002e-04
# Epoch 49/200
# 220/220 [==============================] - 20s 90ms/step - loss: 4.6826e-04 - val_loss: 2.2368e-04
# Epoch 50/200
# 220/220 [==============================] - 19s 85ms/step - loss: 4.6019e-04 - val_loss: 2.1684e-04
# Epoch 51/200
# 220/220 [==============================] - 20s 90ms/step - loss: 4.5496e-04 - val_loss: 2.4751e-04
# Epoch 52/200
# 220/220 [==============================] - 19s 85ms/step - loss: 4.4540e-04 - val_loss: 2.1881e-04
# Epoch 53/200
# 220/220 [==============================] - 20s 90ms/step - loss: 4.3629e-04 - val_loss: 2.1081e-04
# Epoch 54/200
# 220/220 [==============================] - 19s 85ms/step - loss: 4.3071e-04 - val_loss: 1.9563e-04
# Epoch 55/200
# 220/220 [==============================] - 20s 90ms/step - loss: 4.2847e-04 - val_loss: 1.9165e-04
# Epoch 56/200
# 220/220 [==============================] - 19s 85ms/step - loss: 4.2274e-04 - val_loss: 1.9045e-04
# Epoch 57/200
# 220/220 [==============================] - 20s 90ms/step - loss: 4.2056e-04 - val_loss: 2.4588e-04
# Epoch 58/200
# 220/220 [==============================] - 19s 85ms/step - loss: 4.1310e-04 - val_loss: 2.0957e-04
# Epoch 59/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.9927e-04 - val_loss: 1.9581e-04
# Epoch 60/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.9407e-04 - val_loss: 1.8389e-04
# Epoch 61/200
# 220/220 [==============================] - 20s 90ms/step - loss: 4.1066e-04 - val_loss: 1.7827e-04
# Epoch 62/200
# 220/220 [==============================] - 19s 85ms/step - loss: 4.1103e-04 - val_loss: 1.6460e-04
# Epoch 63/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.9003e-04 - val_loss: 1.9819e-04
# Epoch 64/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.7521e-04 - val_loss: 1.8954e-04
# Epoch 65/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.8415e-04 - val_loss: 1.7856e-04
# Epoch 66/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.7864e-04 - val_loss: 1.7546e-04
# Epoch 67/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.6514e-04 - val_loss: 1.8762e-04
# Epoch 68/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.7631e-04 - val_loss: 1.9096e-04
# Epoch 69/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.7744e-04 - val_loss: 1.7260e-04
# Epoch 70/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.7976e-04 - val_loss: 1.8333e-04
# Epoch 71/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.5795e-04 - val_loss: 1.7424e-04
# Epoch 72/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.6904e-04 - val_loss: 2.1958e-04
# Epoch 73/200
# 220/220 [==============================] - 19s 86ms/step - loss: 3.6504e-04 - val_loss: 1.4769e-04
# Epoch 74/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.6266e-04 - val_loss: 1.5995e-04
# Epoch 75/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.6171e-04 - val_loss: 1.8705e-04
# Epoch 76/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.5796e-04 - val_loss: 2.0168e-04
# Epoch 77/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.3846e-04 - val_loss: 2.0914e-04
# Epoch 78/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.5274e-04 - val_loss: 1.8382e-04
# Epoch 79/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.6000e-04 - val_loss: 1.5292e-04
# Epoch 80/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.4670e-04 - val_loss: 1.4906e-04
# Epoch 81/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.4210e-04 - val_loss: 1.4172e-04
# Epoch 82/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.4091e-04 - val_loss: 1.7914e-04
# Epoch 83/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.4630e-04 - val_loss: 2.0392e-04
# Epoch 84/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.3640e-04 - val_loss: 1.6402e-04
# Epoch 85/200
# 220/220 [==============================] - 19s 86ms/step - loss: 3.3576e-04 - val_loss: 1.5420e-04
# Epoch 86/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.3993e-04 - val_loss: 1.6628e-04
# Epoch 87/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.2334e-04 - val_loss: 1.6354e-04
# Epoch 88/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.2511e-04 - val_loss: 1.7933e-04
# Epoch 89/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.2300e-04 - val_loss: 1.7511e-04
# Epoch 90/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.1509e-04 - val_loss: 1.3899e-04
# Epoch 91/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.2961e-04 - val_loss: 1.8195e-04
# Epoch 92/200
# 220/220 [==============================] - 20s 91ms/step - loss: 3.2097e-04 - val_loss: 1.5229e-04
# Epoch 93/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.1840e-04 - val_loss: 1.4593e-04
# Epoch 94/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.1680e-04 - val_loss: 1.9096e-04
# Epoch 95/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.2270e-04 - val_loss: 1.6166e-04
# Epoch 96/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.0896e-04 - val_loss: 1.5915e-04
# Epoch 97/200
# 220/220 [==============================] - 19s 86ms/step - loss: 3.2783e-04 - val_loss: 1.6448e-04
# Epoch 98/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.0726e-04 - val_loss: 1.6471e-04
# Epoch 99/200
# 220/220 [==============================] - 20s 90ms/step - loss: 3.1779e-04 - val_loss: 1.4414e-04
# Epoch 100/200
# 220/220 [==============================] - 19s 86ms/step - loss: 3.1557e-04 - val_loss: 1.5644e-04
# Epoch 101/200
# 220/220 [==============================] - 20s 89ms/step - loss: 3.0531e-04 - val_loss: 1.8020e-04
# Epoch 102/200
# 220/220 [==============================] - 19s 85ms/step - loss: 3.1085e-04 - val_loss: 1.5315e-04
# Epoch 103/200
# 220/220 [==============================] - 19s 88ms/step - loss: 3.0364e-04 - val_loss: 1.6637e-04
# Epoch 104/200
# 220/220 [==============================] - 18s 84ms/step - loss: 3.0653e-04 - val_loss: 1.7080e-04
# Epoch 105/200
# 220/220 [==============================] - 19s 87ms/step - loss: 2.9888e-04 - val_loss: 1.4517e-04
# Epoch 106/200
# 220/220 [==============================] - 18s 83ms/step - loss: 3.0984e-04 - val_loss: 1.4181e-04
# Epoch 107/200
# 220/220 [==============================] - 19s 87ms/step - loss: 3.0243e-04 - val_loss: 1.5709e-04
# Epoch 108/200
# 220/220 [==============================] - 18s 83ms/step - loss: 2.8838e-04 - val_loss: 1.3757e-04
# Epoch 109/200
# 220/220 [==============================] - 19s 87ms/step - loss: 2.9120e-04 - val_loss: 1.3657e-04
# Epoch 110/200
# 220/220 [==============================] - 18s 84ms/step - loss: 2.8670e-04 - val_loss: 1.3413e-04
# Epoch 111/200
# 220/220 [==============================] - 19s 88ms/step - loss: 2.9028e-04 - val_loss: 1.5829e-04
# Epoch 112/200
# 220/220 [==============================] - 18s 83ms/step - loss: 2.7792e-04 - val_loss: 1.3724e-04
# Epoch 113/200
# 220/220 [==============================] - 19s 87ms/step - loss: 2.8352e-04 - val_loss: 1.6231e-04
# Epoch 114/200
# 220/220 [==============================] - 18s 83ms/step - loss: 2.9099e-04 - val_loss: 1.3036e-04
# Epoch 115/200
# 220/220 [==============================] - 19s 88ms/step - loss: 2.8352e-04 - val_loss: 1.5028e-04
# Epoch 116/200
# 220/220 [==============================] - 18s 84ms/step - loss: 2.8250e-04 - val_loss: 1.9915e-04
# Epoch 117/200
# 220/220 [==============================] - 19s 88ms/step - loss: 2.8314e-04 - val_loss: 1.5453e-04
# Epoch 118/200
# 220/220 [==============================] - 18s 84ms/step - loss: 2.8328e-04 - val_loss: 1.3276e-04
# Epoch 119/200
# 220/220 [==============================] - 19s 88ms/step - loss: 2.7093e-04 - val_loss: 1.7092e-04
# Epoch 120/200
# 220/220 [==============================] - 18s 84ms/step - loss: 2.8210e-04 - val_loss: 1.1917e-04
# Epoch 121/200
# 220/220 [==============================] - 19s 88ms/step - loss: 2.6534e-04 - val_loss: 1.5747e-04
# Epoch 122/200
# 220/220 [==============================] - 19s 85ms/step - loss: 2.7592e-04 - val_loss: 1.3320e-04
# Epoch 123/200
# 220/220 [==============================] - 20s 89ms/step - loss: 2.7637e-04 - val_loss: 1.2850e-04
# Epoch 124/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.7522e-04 - val_loss: 1.2820e-04
# Epoch 125/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.7049e-04 - val_loss: 1.2137e-04
# Epoch 126/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.6680e-04 - val_loss: 1.2791e-04
# Epoch 127/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.6398e-04 - val_loss: 1.2626e-04
# Epoch 128/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.6644e-04 - val_loss: 1.2077e-04
# Epoch 129/200
# 220/220 [==============================] - 19s 85ms/step - loss: 2.6131e-04 - val_loss: 1.5918e-04
# Epoch 130/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.6857e-04 - val_loss: 1.3981e-04
# Epoch 131/200
# 220/220 [==============================] - 19s 85ms/step - loss: 2.6464e-04 - val_loss: 1.2599e-04
# Epoch 132/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.6128e-04 - val_loss: 1.4636e-04
# Epoch 133/200
# 220/220 [==============================] - 19s 87ms/step - loss: 2.6345e-04 - val_loss: 1.2903e-04
# Epoch 134/200
# 220/220 [==============================] - 19s 88ms/step - loss: 2.5734e-04 - val_loss: 1.1654e-04
# Epoch 135/200
# 220/220 [==============================] - 20s 92ms/step - loss: 2.5857e-04 - val_loss: 1.2146e-04
# Epoch 136/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.5240e-04 - val_loss: 1.2886e-04
# Epoch 137/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.5500e-04 - val_loss: 1.4199e-04
# Epoch 138/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.5267e-04 - val_loss: 1.3290e-04
# Epoch 139/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.4202e-04 - val_loss: 1.1174e-04
# Epoch 140/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.5065e-04 - val_loss: 1.5003e-04
# Epoch 141/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.5183e-04 - val_loss: 1.0135e-04
# Epoch 142/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.4406e-04 - val_loss: 1.3958e-04
# Epoch 143/200
# 220/220 [==============================] - 20s 89ms/step - loss: 2.4812e-04 - val_loss: 1.4697e-04
# Epoch 144/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.4350e-04 - val_loss: 1.6213e-04
# Epoch 145/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.4589e-04 - val_loss: 1.1618e-04
# Epoch 146/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.4627e-04 - val_loss: 1.2680e-04
# Epoch 147/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.5415e-04 - val_loss: 1.3897e-04
# Epoch 148/200
# 220/220 [==============================] - 21s 95ms/step - loss: 2.4184e-04 - val_loss: 1.1336e-04
# Epoch 149/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.3435e-04 - val_loss: 1.0563e-04
# Epoch 150/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.3410e-04 - val_loss: 1.5739e-04
# Epoch 151/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.4340e-04 - val_loss: 1.0663e-04
# Epoch 152/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.3284e-04 - val_loss: 1.1244e-04
# Epoch 153/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.4433e-04 - val_loss: 1.0616e-04
# Epoch 154/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.3439e-04 - val_loss: 1.0656e-04
# Epoch 155/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.3760e-04 - val_loss: 1.1367e-04
# Epoch 156/200
# 220/220 [==============================] - 20s 89ms/step - loss: 2.3695e-04 - val_loss: 1.3887e-04
# Epoch 157/200
# 220/220 [==============================] - 19s 87ms/step - loss: 2.3500e-04 - val_loss: 1.2358e-04
# Epoch 158/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.2647e-04 - val_loss: 1.2600e-04
# Epoch 159/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.3321e-04 - val_loss: 8.9618e-05
# Epoch 160/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.3102e-04 - val_loss: 9.2987e-05
# Epoch 161/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.2526e-04 - val_loss: 1.1847e-04
# Epoch 162/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.3881e-04 - val_loss: 9.8038e-05
# Epoch 163/200
# 220/220 [==============================] - 20s 89ms/step - loss: 2.2974e-04 - val_loss: 1.1520e-04
# Epoch 164/200
# 220/220 [==============================] - 19s 87ms/step - loss: 2.2161e-04 - val_loss: 9.8888e-05
# Epoch 165/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.2938e-04 - val_loss: 9.8371e-05
# Epoch 166/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.2495e-04 - val_loss: 1.0912e-04
# Epoch 167/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.2864e-04 - val_loss: 9.9908e-05
# Epoch 168/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.1983e-04 - val_loss: 9.6290e-05
# Epoch 169/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.2406e-04 - val_loss: 9.5509e-05
# Epoch 170/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.1668e-04 - val_loss: 9.0481e-05
# Epoch 171/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.2839e-04 - val_loss: 9.7191e-05
# Epoch 172/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.1910e-04 - val_loss: 9.2300e-05
# Epoch 173/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.1662e-04 - val_loss: 8.9081e-05
# Epoch 174/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.1176e-04 - val_loss: 1.0977e-04
# Epoch 175/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.2267e-04 - val_loss: 1.2396e-04
# Epoch 176/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.1398e-04 - val_loss: 9.5034e-05
# Epoch 177/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.1824e-04 - val_loss: 1.3388e-04
# Epoch 178/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.1776e-04 - val_loss: 1.1459e-04
# Epoch 179/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.1007e-04 - val_loss: 8.3009e-05
# Epoch 180/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.2284e-04 - val_loss: 1.0137e-04
# Epoch 181/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.2535e-04 - val_loss: 9.3305e-05
# Epoch 182/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.0917e-04 - val_loss: 9.0275e-05
# Epoch 183/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.0875e-04 - val_loss: 8.8552e-05
# Epoch 184/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.1475e-04 - val_loss: 1.0348e-04
# Epoch 185/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.1572e-04 - val_loss: 1.0807e-04
# Epoch 186/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.1311e-04 - val_loss: 8.7623e-05
# Epoch 187/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.0531e-04 - val_loss: 8.0173e-05
# Epoch 188/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.0643e-04 - val_loss: 8.4406e-05
# Epoch 189/200
# 220/220 [==============================] - 21s 95ms/step - loss: 2.0275e-04 - val_loss: 9.6282e-05
# Epoch 190/200
# 220/220 [==============================] - 21s 94ms/step - loss: 2.1645e-04 - val_loss: 1.2829e-04
# Epoch 191/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.1514e-04 - val_loss: 1.0560e-04
# Epoch 192/200
# 220/220 [==============================] - 20s 90ms/step - loss: 2.1888e-04 - val_loss: 9.7454e-05
# Epoch 193/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.0737e-04 - val_loss: 1.3625e-04
# Epoch 194/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.0471e-04 - val_loss: 1.2519e-04
# Epoch 195/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.1573e-04 - val_loss: 1.0090e-04
# Epoch 196/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.1073e-04 - val_loss: 1.2653e-04
# Epoch 197/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.0346e-04 - val_loss: 9.6485e-05
# Epoch 198/200
# 220/220 [==============================] - 19s 86ms/step - loss: 2.0566e-04 - val_loss: 1.2251e-04
# Epoch 199/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.0735e-04 - val_loss: 9.6904e-05
# Epoch 200/200
# 220/220 [==============================] - 20s 91ms/step - loss: 2.0593e-04 - val_loss: 1.0325e-04

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 238)               228480
#
#  dropout_1 (Dropout)         (None, 238)               0
#
#  dense_1 (Dense)             (None, 1)                 239
#
# =================================================================
# Total params: 228719 (893.43 KB)
# Trainable params: 228719 (893.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from matplotlib import pyplot
import matplotlib.pyplot as plt

# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error


y_pred = model.predict(X_test)  #test
y_pred_train = model.predict(X_train) #train
#y_pred_val = model.predict(X_validate)  #val


#inverse
#train inv
y_train_inv = t_transformer.inverse_transform(y_train.reshape(1, -1))  #train actual
y_pred_train_inv = t_transformer.inverse_transform(y_pred_train)  #train

#test inv
y_test_inv = t_transformer.inverse_transform(y_test.reshape((len(y_test), 1)))  #test_actual
y_pred_inv = t_transformer.inverse_transform(y_pred)  #test

#val inv
#y_validate_inv = t_transformer.inverse_transform(y_validate.reshape(-1, 1))
#y_pred_val_inv = t_transformer.inverse_transform(y_pred_val)
# Out:
# 137/137 [==============================] - 3s 20ms/step
# 550/550 [==============================] - 12s 22ms/step

# %% [markdown]
# Train

# %%
y_train_inv2 = (y_train_inv.reshape(-1, 1))
#y_train_inv2.shape


# calculate RMSE
rmse = sqrt(mean_squared_error(y_train_inv2, y_pred_train_inv))
print('Train RMSE: %.9f' % rmse)


# calculate MAE
from sklearn.metrics import mean_absolute_error
mae= mean_absolute_error(y_train_inv2, y_pred_train_inv)
print('Train MAE: %.9f' % mae)


# calculate MAPE
from sklearn.metrics import mean_absolute_percentage_error
mape= mean_absolute_percentage_error(y_train_inv2, y_pred_train_inv)
print('Train MAPE: %.9f' % mape)

# calculate NRMSE
actual_test=y_train_inv2
Nrmse_test=rmse /(actual_test.max() - actual_test.min())
print('Train NRMSE: %.9f' % Nrmse_test)


from sklearn.metrics import r2_score
r2 = r2_score(y_train_inv2, y_pred_train_inv)
print('R2 score: %.9f' % r2)
# Out:
# Train RMSE: 5.484650671
# Train MAE: 4.005272331
# Train MAPE: 0.009794196
# Train NRMSE: 0.010726908
# R2 score: 0.997956602

# %% [markdown]
# Test

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(y_test_inv, y_pred_inv))
print('Test RMSE: %.9f' % rmse)


# calculate MAE
from sklearn.metrics import mean_absolute_error
mae= mean_absolute_error(y_test_inv, y_pred_inv)
print('Test MAE: %.9f' % mae)


# calculate MAPE
from sklearn.metrics import mean_absolute_percentage_error
mape= mean_absolute_percentage_error(y_test_inv, y_pred_inv)
print('Test MAPE: %.9f' % mape)

# calculate NRMSE
actual_test=y_test_inv
Nrmse_test=rmse /(actual_test.max() - actual_test.min())
print('Test NRMSE: %.9f' % Nrmse_test)


from sklearn.metrics import r2_score
r2 = r2_score(y_test_inv, y_pred_inv)
print('R2 score: %.9f' % r2)
# Out:
# Test RMSE: 14.705808027
# Test MAE: 8.978969603
# Test MAPE: 0.015979437
# Test NRMSE: 0.028789636
# R2 score: 0.976230706

# %%
# Create a DataFrame with predicted and actual values
df_results = pd.DataFrame({
    #"Datetime": Datetime_column,  # Replace with your datetime column
    "Predicted": y_pred_inv.flatten(),
    "Actual": y_test_inv.flatten()
})

# Print the DataFrame
print(df_results)
# Out:
#        Predicted      Actual
# 0     288.866669  291.394602
# 1     288.571381  297.254720
# 2     300.094055  301.377388
# 3     309.923981  311.993927
# 4     357.124725  349.286351
# ...          ...         ...
# 4372  648.271423  632.235500
# 4373  619.292786  612.703162
# 4374  587.576599  589.574385
# 4375  556.790222  561.323968
# 4376  522.248962  522.105758
#
# [4377 rows x 2 columns]

# %%
plt.figure(figsize=(15,6))

plt.plot(y_pred_inv, label="Prediction" )
plt.plot(y_test_inv, label="Actual")
plt.legend()
plt.ylabel('Load')
plt.xlabel('time step' )
#plt.title ("Russell 2000 Adj close Price prediction- with MAE {:10.4f}".format(mae))
plt.title ('Load forecasting')

#plt.xlim(
#  xmin=-10, xmax=2200
#)
#plt.show()


#plt.savefig("ALLSKY_SRF_ALB.svg")
#plt.savefig("ALLSKY_SRF_ALB.png", format="png", dpi=300)
#plt.savefig('ALLSKY_SRF_ALB.eps', format='eps')
# Out:
# Text(0.5, 1.0, 'Load forecasting')

# %%
#zoom in spikes


plt.figure(figsize=(15,6))

plt.plot(y_test_inv[1000:1500])
plt.plot(y_pred_inv[1000:1500])
plt.xlim(
  xmin=0, xmax=500
)
#plt.show()




plt.savefig("SZA_zoomin.svg")
plt.savefig("SZA_zoomin.png", format="png", dpi=300)
plt.savefig('SZA_zoomin.eps', format='eps')
